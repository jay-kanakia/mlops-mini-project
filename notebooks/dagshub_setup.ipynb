# %%
import dagshub
dagshub.init(repo_owner='jay-kanakia', repo_name='mlops-mini-project', mlflow=True)

import mlflow
with mlflow.start_run():
  mlflow.log_param('parameter name', 'value')
  mlflow.log_metric('metric name', 1)
# Out:
# Initialized MLflow to track repo "jay-kanakia/mlops-mini-project"
# Repository jay-kanakia/mlops-mini-project initialized!
# 🏃 View run amazing-moose-450 at: https://dagshub.com/jay-kanakia/mlops-mini-project.mlflow/#/experiments/0/runs/f0df924dd32c4667917540802a758d1b
# 🧪 View experiment at: https://dagshub.com/jay-kanakia/mlops-mini-project.mlflow/#/experiments/0

# %%
# https://dagshub.com/jay-kanakia/mlops-mini-project.mlflow
