# %%
# register model

import json
import mlflow
import logging

import dagshub

mlflow.set_tracking_uri('https://dagshub.com/jay-kanakia/mlops-mini-project.mlflow')
dagshub.init(repo_owner='jay-kanakia', repo_name='mlops-mini-project', mlflow=True)


def main():
    model_uri = f"runs:/b8b13f86594344fabf8c2d7cc46236ce/rf_model"    
    model_name = "model-run"
    model_version = mlflow.register_model(model_uri, model_name)
    
    print(model_version.name)        # e.g., "my_model"
    print(model_version.version)     # e.g., 1
    print(model_version.current_stage)  # e.g., "None"
    print(model_version.run_id)

if __name__ == '__main__':
    main()
# Out:
# Accessing as jay-kanakia
# Initialized MLflow to track repo "jay-kanakia/mlops-mini-project"
# Repository jay-kanakia/mlops-mini-project initialized!
# Registered model 'model-run' already exists. Creating a new version of this model...
# ---------------------------------------------------------------------------
# RestException                             Traceback (most recent call last)
# Cell In[1], line 24
#      21     print(model_version.run_id)
#      23 if __name__ == '__main__':
# ---> 24     main()
#
# Cell In[1], line 16, in main()
#      14 model_uri = f"runs:/b8b13f86594344fabf8c2d7cc46236ce/rf_model"
#      15 model_name = "model-run"
# ---> 16 model_version = mlflow.register_model(model_uri, model_name)
#      18 print(model_version.name)        # e.g., "my_model"
#      19 print(model_version.version)     # e.g., 1
#
# ...
